# %% [markdown]
# # Model

# %%
import os
import glob
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, LSTM, Input, Lambda, RepeatVector, TimeDistributed, Bidirectional, Dropout
from tensorflow.keras import backend as K
from tensorflow.keras.losses import mse
from tensorflow.keras.callbacks import EarlyStopping

# Function to load and process flight data
def load_and_process_flight_data(file_paths):
    flights = []
    for file_path in file_paths:
        df = pd.read_csv(file_path, delimiter='\t')
        if 'Time(milli)' in df.columns:
            df = df.drop(columns=['Time(milli)'])
        flights.append(df.values)
    return flights

# Directory containing the adjusted flight data files
adjusted_data_directory = './data/adjusted_flights/'
adjusted_file_pattern = os.path.join(adjusted_data_directory, 'SimuladorDeVoo_*.txt')
adjusted_files = glob.glob(adjusted_file_pattern)

# Load and process the adjusted flight data
flight_data = load_and_process_flight_data(adjusted_files)

# Normalize the data
all_data = np.concatenate(flight_data, axis=0)
data_mean = np.mean(all_data, axis=0)
data_std = np.std(all_data, axis=0)
data_std[data_std == 0] = 1e-8  # Add a small value where std is 0 to avoid division by zero

flight_data = [(df - data_mean) / data_std for df in flight_data]

# Find the maximum length of flights
max_length = max(len(df) for df in flight_data)

# Pad all flights to have the same length
padded_flights = np.array([np.pad(df, ((0, max_length - len(df)), (0, 0)), mode='constant') for df in flight_data])

# Define the VAE architecture
timesteps = max_length
input_dim = padded_flights.shape[2]
latent_dim = 50  # Increased latent dimension

# Encoder part of the VAE
inputs = Input(shape=(timesteps, input_dim))
h = Bidirectional(LSTM(256, return_sequences=False, kernel_regularizer=tf.keras.regularizers.l2(0.01)))(inputs)
h = Dense(128, activation='relu')(h)
h = Dropout(0.3)(h)  # Added dropout for regularization

# Latent space representation
z_mean = Dense(latent_dim)(h)
z_log_var = Dense(latent_dim)(h)

# Sampling function to generate latent vectors
def sampling(args):
    z_mean, z_log_var = args
    batch = K.shape(z_mean)[0]
    dim = K.int_shape(z_mean)[1]
    epsilon = K.random_normal(shape=(batch, dim))
    return z_mean + K.exp(0.5 * z_log_var) * epsilon

z = Lambda(sampling, output_shape=(latent_dim,))([z_mean, z_log_var])

# Decoder part of the VAE
decoder_h = Dense(128, activation='relu')
h_decoded = decoder_h(RepeatVector(timesteps)(z))
h_decoded = Dropout(0.3)(h_decoded)  # Apply dropout to the output of the Dense layer
decoder_mean = LSTM(256, return_sequences=True)
decoder_output = TimeDistributed(Dense(input_dim, activation='linear'))

x_decoded_mean = decoder_mean(h_decoded)
x_decoded_mean = decoder_output(x_decoded_mean)

# Define the VAE model
vae = Model(inputs, x_decoded_mean)

# Define the VAE loss
reconstruction_loss = mse(inputs, x_decoded_mean)
reconstruction_loss = K.sum(reconstruction_loss, axis=[1])  # Sum over the timesteps
kl_loss = 1 + z_log_var - K.square(z_mean) - K.exp(z_log_var)
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= -0.5
kl_weight = 0.001  # Weighted KL divergence
vae_loss = K.mean(reconstruction_loss + kl_weight * kl_loss)

vae.add_loss(vae_loss)

# Learning rate scheduling
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-3,
    decay_steps=10000,
    decay_rate=0.9
)

optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)
vae.compile(optimizer=optimizer)
vae.summary()

# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Train the VAE with early stopping
vae.fit(padded_flights, epochs=1_000_000, batch_size=32, validation_split=0.2, callbacks=[early_stopping])

# Extract the decoder model
decoder_input = Input(shape=(latent_dim,))
_h_decoded = RepeatVector(timesteps)(decoder_input)
_h_decoded = decoder_h(_h_decoded)
_x_decoded_mean = decoder_mean(_h_decoded)
_x_decoded_mean = decoder_output(_x_decoded_mean)

decoder = Model(decoder_input, _x_decoded_mean)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 39, 21)]             0         []
#
#  bidirectional_1 (Bidirecti  (None, 512)                  569344    ['input_3[0][0]']
#  onal)
#
#  dense_5 (Dense)             (None, 128)                  65664     ['bidirectional_1[0][0]']
#
#  dropout_2 (Dropout)         (None, 128)                  0         ['dense_5[0][0]']
#
#  dense_6 (Dense)             (None, 50)                   6450      ['dropout_2[0][0]']
#
#  dense_7 (Dense)             (None, 50)                   6450      ['dropout_2[0][0]']
#
#  lambda_1 (Lambda)           (None, 50)                   0         ['dense_6[0][0]',
#                                                                      'dense_7[0][0]']
#
#  repeat_vector_2 (RepeatVec  (None, 39, 50)               0         ['lambda_1[0][0]']
#  tor)
#
#  dense_8 (Dense)             (None, 39, 128)              6528      ['repeat_vector_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 39, 128)              0         ['dense_8[0][0]']
#
#  lstm_3 (LSTM)               (None, 39, 256)              394240    ['dropout_3[0][0]']
#
#  time_distributed_1 (TimeDi  (None, 39, 21)               5397      ['lstm_3[0][0]']
#  stributed)
#
#  tf.__operators__.add_2 (TF  (None, 50)                   0         ['dense_7[0][0]']
#  OpLambda)
#
#  tf.math.square_1 (TFOpLamb  (None, 50)                   0         ['dense_6[0][0]']
#  da)
#
#  tf.math.subtract_2 (TFOpLa  (None, 50)                   0         ['tf.__operators__.add_2[0][0]
#  mbda)                                                              ',
#                                                                      'tf.math.square_1[0][0]']
#
#  tf.math.exp_1 (TFOpLambda)  (None, 50)                   0         ['dense_7[0][0]']
#
#  tf.convert_to_tensor_1 (TF  (None, 39, 21)               0         ['time_distributed_1[0][0]']
#  OpLambda)
#
#  tf.cast_1 (TFOpLambda)      (None, 39, 21)               0         ['input_3[0][0]']
#
#  tf.math.subtract_3 (TFOpLa  (None, 50)                   0         ['tf.math.subtract_2[0][0]',
#  mbda)                                                               'tf.math.exp_1[0][0]']
#
#  tf.math.squared_difference  (None, 39, 21)               0         ['tf.convert_to_tensor_1[0][0]
#  _1 (TFOpLambda)                                                    ',
#                                                                      'tf.cast_1[0][0]']
#
#  tf.math.reduce_sum_3 (TFOp  (None,)                      0         ['tf.math.subtract_3[0][0]']
#  Lambda)
#
#  tf.math.reduce_mean_2 (TFO  (None, 39)                   0         ['tf.math.squared_difference_1
#  pLambda)                                                           [0][0]']
#
#  tf.math.multiply_2 (TFOpLa  (None,)                      0         ['tf.math.reduce_sum_3[0][0]']
#  mbda)
#
#  tf.math.reduce_sum_2 (TFOp  (None,)                      0         ['tf.math.reduce_mean_2[0][0]'
#  Lambda)                                                            ]
#
#  tf.math.multiply_3 (TFOpLa  (None,)                      0         ['tf.math.multiply_2[0][0]']
#  mbda)
#
#  tf.__operators__.add_3 (TF  (None,)                      0         ['tf.math.reduce_sum_2[0][0]',
#  OpLambda)                                                           'tf.math.multiply_3[0][0]']
#
#  tf.math.reduce_mean_3 (TFO  ()                           0         ['tf.__operators__.add_3[0][0]
#  pLambda)                                                           ']
#
#  add_loss_1 (AddLoss)        ()                           0         ['tf.math.reduce_mean_3[0][0]'
#                                                                     ]
#
# ==================================================================================================
# Total params: 1054073 (4.02 MB)
# Trainable params: 1054073 (4.02 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/1000000
# 1/1 [==============================] - 7s 7s/step - loss: 42.2929 - val_loss: 42.4124
# Epoch 2/1000000
# 1/1 [==============================] - 0s 131ms/step - loss: 40.9460 - val_loss: 42.2564
# Epoch 3/1000000
# 1/1 [==============================] - 0s 110ms/step - loss:
1000000
# 1/1 [==============================] - 0s 113ms/step - loss: 18.6774 - val_loss: 22.6995
# Epoch 49/1000000
# 1/1 [==============================] - 0s 117ms/step - loss: 19.0145 - val_loss: 22.6523
# Epoch 50/1000000
# 1/1 [==============================] - 0s 122ms/step - loss: 18.7123 - val_loss: 21.7540
# Epoch 51/1000000
# 1/1 [==============================] - 0s 118ms/step - loss: 18.4748 - val_loss: 21.4342
# Epoch 52/1000000
# 1/1 [==============================] - 0s 112ms/step - loss: 18.3632 - val_loss: 22.1802
# Epoch 53/1000000
# 1/1 [==============================] - 0s 117ms/step - loss: 18.7041 - val_loss: 20.7101
# Epoch 54/1000000
# 1/1 [==============================] - 0s 115ms/step - loss: 17.5214 - val_loss: 21.6312
# Epoch 55/1000000
# 1/1 [==============================] - 0s 107ms/step - loss: 18.2088 - val_loss: 20.3077
# Epoch 56/1000000
# 1/1 [==============================] - 0s 107ms/step - loss: 17.3404 - val_loss: 21.6611
# Epoch 57/1000000
# 1/1 [==============================] - 0s 113ms/step - loss: 17.7765 - val_loss: 20.4106
# Epoch 58/1000000
# 1/1 [==============================] - 0s 105ms/step - loss: 16.7261 - val_loss: 20.3697
# Epoch 59/1000000
# 1/1 [==============================] - 0s 112ms/step - loss: 16.9941 - val_loss: 19.8195
# Epoch 60/1000000
# 1/1 [==============================] - 0s 106ms/step - loss: 16.5177 - val_loss: 20.6331
# Epoch 61/1000000
# 1/1 [==============================] - 0s 113ms/step - loss: 16.3248 - val_loss: 19.4889
# Epoch 62/1000000
# 1/1 [==============================] - 0s 110ms/step - loss: 16.1442 - val_loss: 19.5822
# Epoch 63/1000000
# 1/1 [==============================] - 0s 108ms/step - loss: 16.2506 - val_loss: 19.6556
# Epoch 64/1000000
# 1/1 [==============================] - 0s 108ms/step - loss: 15.9210 - val_loss: 19.4272
# Epoch 65/1000000
# 1/1 [==============================] - 0s 112ms/step - loss: 15.8018 - val_loss: 19.0187
# Epoch 66/1000000
# 1/1 [==============================] - 0s 124ms/step - loss: 15.3373 - val_loss: 18.9717
# Epoch 67/1000000
# 1/1 [==============================] - 0s 113ms/step - loss: 15.6815 - val_loss: 19.3708
# Epoch 68/1000000
# 1/1 [==============================] - 0s 114ms/step - loss: 16.1674 - val_loss: 18.7334
# Epoch 69/1000000
# 1/1 [==============================] - 0s 115ms/step - loss: 15.2880 - val_loss: 18.5953
# Epoch 70/1000000
# 1/1 [==============================] - 0s 110ms/step - loss: 15.3498 - val_loss: 18.7163
# Epoch 71/1000000
# 1/1 [==============================] - 0s 106ms/step - loss: 15.3450 - val_loss: 18.6942
# Epoch 72/1000000
# 1/1 [==============================] - 0s 110ms/step - loss: 15.8769 - val_loss: 18.7464
# Epoch 73/1000000
# 1/1 [==============================] - 0s 109ms/step - loss: 15.7692 - val_loss: 18.7526
# Epoch 74/1000000
# 1/1 [==============================] - 0s 111ms/step - loss: 14.5987 - val_loss: 18.9768
# Epoch 75/1000000
# 1/1 [==============================] - 0s 115ms/step - loss: 15.5550 - val_loss: 19.3005
# Epoch 76/1000000
# 1/1 [==============================] - 0s 117ms/step - loss: 16.0403 - val_loss: 17.8817
# Epoch 77/1000000
# 1/1 [==============================] - 0s 115ms/step - loss: 14.6922 - val_loss: 19.8212
# Epoch 78/1000000
# 1/1 [==============================] - 0s 111ms/step - loss: 15.3196 - val_loss: 18.1949
# Epoch 79/1000000
# 1/1 [==============================] - 0s 111ms/step - loss: 14.6420 - val_loss: 18.8137
# Epoch 80/1000000
# 1/1 [==============================] - 0s 111ms/step - loss: 15.2984 - val_loss: 18.8411
# Epoch 81/1000000
# 1/1 [==============================] - 0s 117ms/step - loss: 14.5326 - val_loss: 19.7664
# Epoch 82/1000000
# 1/1 [==============================] - 0s 109ms/step - loss: 16.5407 - val_loss: 19.2301
# Epoch 83/1000000
# 1/1 [==============================] - 0s 109ms/step - loss: 17.1622 - val_loss: 18.1228
# Epoch 84/1000000
# 1/1 [==============================] - 0s 110ms/step - loss: 14.8061 - val_loss: 19.6970
# Epoch 85/1000000
# 1/1 [==============================] - 0s 117ms/step - loss: 15.6976 - val_loss: 19.0145
# Epoch 86/1000000
# 1/1 [==============================] - 0s 115ms/step - loss: 14.8124 - val_loss: 18.6371
# Epoch 87/1000000
# 1/1 [==============================] - 0s 110ms/step - loss: 15.5602 - val_loss: 18.6151
# Epoch 88/1000000
# 1/1 [==============================] - 0s 109ms/step - loss: 15.6006 - val_loss: 20.1931
# Epoch 89/1000000
# 1/1 [==============================] - 0s 109ms/step - loss: 15.1175 - val_loss: 19.3413
# Epoch 90/1000000
# 1/1 [==============================] - 0s 109ms/step - loss: 15.2328 - val_loss: 18.3107
# Epoch 91/1000000
# 1/1 [==============================] - 0s 105ms/step - loss: 14.2381 - val_loss: 18.0441
# Epoch 92/1000000
# 1/1 [==============================] - 0s 106ms/step - loss: 15.2449 - val_loss: 18.2061
# Epoch 93/1000000
# 1/1 [==============================] - 0s 107ms/step - loss: 14.0738 - val_loss: 19.6713
# Epoch 94/1000000
# 1/1 [==============================] - 0s 109ms/step - loss: 15.4412 - val_loss: 18.1355
# Epoch 95/1000000
# 1/1 [==============================] - 0s 116ms/step - loss: 14.1765 - val_loss: 17.9695
# Epoch 96/1000000
# 1/1 [==============================] - 0s 115ms/step - loss: 14.6885 - val_loss: 17.7467
# Epoch 97/1000000
# 1/1 [==============================] - 0s 115ms/step - loss: 14.4578 - val_loss: 18.3785
# Epoch 98/1000000
# 1/1 [==============================] - 0s 112ms/step - loss: 14.0791 - val_loss: 19.2441
# Epoch 99/1000000
# 1/1 [==============================] - 0s 115ms/step - loss: 14.9656 - val_loss: 17.5375
# Epoch 100/1000000
# 1/1 [==============================] - 0s 115ms/step - loss:
1000000
# 1/1 [==============================] - 0s 109ms/step - loss: 10.1415 - val_loss: 15.3184
# Epoch 291/1000000
# 1/1 [==============================] - 0s 110ms/step - loss: 10.1058 - val_loss: 14.8523
# Epoch 292/1000000
# 1/1 [==============================] - 0s 108ms/step - loss: 10.1872 - val_loss: 14.5067
# Epoch 293/1000000
# 1/1 [==============================] - 0s 109ms/step - loss: 10.6018 - val_loss: 14.7449
# Epoch 294/1000000
# 1/1 [==============================] - 0s 111ms/step - loss: 10.0843 - val_loss: 14.5404
# Epoch 295/1000000
# 1/1 [==============================] - 0s 107ms/step - loss: 9.6585 - val_loss: 14.2145
# Epoch 296/1000000
# 1/1 [==============================] - 0s 113ms/step - loss: 9.9779 - val_loss: 14.7111
# Epoch 297/1000000
# 1/1 [==============================] - 0s 112ms/step - loss: 10.0844 - val_loss: 14.4465
# Epoch 298/1000000
# 1/1 [==============================] - 0s 112ms/step - loss: 10.2228 - val_loss: 15.1144
# Epoch 299/1000000
# 1/1 [==============================] - 0s 112ms/step - loss: 10.1893 - val_loss: 14.4486
# Epoch 300/1000000
# 1/1 [==============================] - 0s 125ms/step - loss: 10.8593 - val_loss: 14.9031

# %%
# Generate new synthetic flight data using the decoder
def generate_synthetic_flights(decoder, num_samples, latent_dim):
    z_samples = np.random.normal(size=(num_samples, latent_dim))
    generated_sequences = decoder.predict(z_samples)
    return (generated_sequences * data_std) + data_mean

num_synthetic_flights_list = [15, 30, 100, 500, 1000, 3000]

for num_synthetic_flights in num_synthetic_flights_list:
    synthetic_flights = generate_synthetic_flights(decoder, num_synthetic_flights, latent_dim)

    # Save the generated sequences
    def save_generated_sequences(sequences, save_dir):
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)

        for i, sample in enumerate(sequences):
            sample_df = pd.DataFrame(sample, columns=[
                'LAT(deg)', 'LON(deg)', 'ALT(m)', 'Phi(deg)', 'Theta(deg)', 'Psi(deg)',
                'Vx(m/s)', 'Vy(m/s)', 'Vz(m/s)', 'P(deg/s)', 'Q(deg/s)', 'R(deg/s)',
                'Nx(m/s2)', 'Ny(m/s2)', 'Nz(m/s2)', 'Radial(deg)', 'Distance(m)', 'DeltaAlt:Anv-Tgt(m)',
                'JX', 'JY', 'Throttle'])
            sample_df.to_csv(os.path.join(save_dir, f'GeneratedFlight_{i+1}.txt'), sep='\t', index=False)

    save_dir = f'./data/generated_flights_{num_synthetic_flights}/'
    save_generated_sequences(synthetic_flights, save_dir)

    print(f'{num_synthetic_flights} synthetic sequences saved to {save_dir}')
# Out:
# 1/1 [==============================] - 0s 400ms/step
# 15 synthetic sequences saved to ./data/generated_flights_15/
# 1/1 [==============================] - 0s 33ms/step
# 30 synthetic sequences saved to ./data/generated_flights_30/
# 4/4 [==============================] - 0s 14ms/step
# 100 synthetic sequences saved to ./data/generated_flights_100/
# 16/16 [==============================] - 0s 18ms/step
# 500 synthetic sequences saved to ./data/generated_flights_500/
# 32/32 [==============================] - 1s 18ms/step
# 1000 synthetic sequences saved to ./data/generated_flights_1000/
# 94/94 [==============================] - 2s 19ms/step
# 3000 synthetic sequences saved to ./data/generated_flights_3000/

# %% [markdown]
# # Metrics
#
# Explicação:
#
# - Diferença das Médias e Desvios Padrão
# Calculamos a diferença das médias e dos desvios padrão entre as amostras reais e geradas. Isso nos dá uma ideia de quão próximas as distribuições de ambas as amostras estão.
#
# - Diferença de Correlação
# A correlação entre as variáveis em ambas as amostras é calculada e comparada. Isso ajuda a verificar se as relações entre as variáveis estão sendo preservadas.
#
# - Distância DTW
# Calculamos a distância DTW média entre as sequências reais e geradas. Essa métrica é útil para medir a similaridade entre duas séries temporais, mesmo que possam ter variações na velocidade.
#
# Interpretação:
#
# - Médias e Desvios Padrão
# Pequenas diferenças indicam que as amostras geradas têm características estatísticas semelhantes às amostras reais.
#
# - Correlação
# Uma diferença de correlação pequena sugere que as relações entre variáveis nas amostras geradas são similares às das reais.
#
# - Distância DTW
# Um valor baixo de DTW indica que as sequências geradas seguem padrões temporais similares aos das sequências reais.
# Essas métricas fornecerão uma visão quantitativa da qualidade das amostras geradas pelo seu modelo GAN. Se os valores de diferença forem baixos e a distância DTW for pequena, isso indicará que as amostras geradas são bastante similares às amostras reais, validando o sucesso do modelo.

# %% [markdown]
# # Plots

# %%
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Function to load flight data from directory
def load_flight_data(directory, pattern='SimuladorDeVoo_*.txt'):
    file_pattern = os.path.join(directory, pattern)
    files = glob.glob(file_pattern)
    flight_data = []
    for file in files:
        df = pd.read_csv(file, delimiter='\t')
        flight_data.append(df)
    return flight_data

# Plotting function
def plot_flights_3d(flight_data, title, ax, elev, azim):
    for flight in flight_data:
        ax.plot(flight['LAT(deg)'], flight['LON(deg)'], flight['ALT(m)'])
    ax.set_xlabel('Latitude (deg)')
    ax.set_ylabel('Longitude (deg)')
    ax.set_zlabel('Altitude (m)')
    ax.set_title(title)
    ax.view_init(elev=elev, azim=azim)

# Load adjusted flights
adjusted_flights_dir = './data/adjusted_flights/'
adjusted_flights = load_flight_data(adjusted_flights_dir)

# Load generated flights
generated_flights_dir = './data/generated_flights_15/'
generated_flights = load_flight_data(generated_flights_dir, pattern='GeneratedFlight_*.txt')

# Create 3D plot
fig = plt.figure(figsize=(12, 6))

# Adjust the view angles: elevation and azimuth
elevation_angle = 30  # Elevation angle in degrees
azimuth_angle = 150   # Azimuth angle in degrees

# Plot adjusted flights
ax1 = fig.add_subplot(121, projection='3d')
plot_flights_3d(adjusted_flights, 'Adjusted Flights', ax1, elevation_angle, azimuth_angle)

# Plot generated flights
ax2 = fig.add_subplot(122, projection='3d')
plot_flights_3d(generated_flights, 'Generated Flights', ax2, elevation_angle, azimuth_angle)

plt.tight_layout()
plt.show()

# %%
#Moving average
def apply_smoothing(data, window_size=10):
    # Applies smoothing with a moving average to each numeric column
    smoothed_data = data.copy()
    smoothed_data.iloc[:, :-3] = data.iloc[:, :-3].rolling(window=window_size, min_periods=1, center=True).mean()
    return smoothed_data

def process_files(input_folder, output_folder):
    # Checks if the output folder exists; if not, creates it
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Iterates over all .txt files in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(".txt"):
            # Full file path
            file_path = os.path.join(input_folder, filename)
            
            # Reads the .txt file into a DataFrame
            df = pd.read_csv(file_path, sep='\t')
            
            # Applies the smoothing
            smoothed_df = apply_smoothing(df)
            
            # Full path for the output file
            output_file_path = os.path.join(output_folder, filename)
            
            # Saves the smoothed file in the output folder
            smoothed_df.to_csv(output_file_path, sep='\t', index=False)
            
            print(f"Smoothing applied and file saved: {output_file_path}")

num_synthetic_flights_list = [15, 30, 100, 500, 1000, 3000]

for num_synthetic_flights in num_synthetic_flights_list:
    # Defines the input and output folders
    input_folder = f'./data/generated_flights_{num_synthetic_flights}'
    output_folder = f'./data/smoothed_flights_{num_synthetic_flights}'

    # Processes the files
    process_files(input_folder, output_folder)
# Out:
# Smoothing applied and file saved: ./data/smoothed_flights_15/GeneratedFlight_14.txt
# Smoothing applied and file saved: ./data/smoothed_flights_15/GeneratedFlight_2.txt
# Smoothing applied and file saved: ./data/smoothed_flights_15/GeneratedFlight_8.txt
# Smoothing applied and file saved: ./data/smoothed_flights_15/GeneratedFlight_3.txt
# Smoothing applied and file saved: ./data/smoothed_flights_15/GeneratedFlight_6.txt
# Smoothing applied and file saved: ./data/smoothed_flights_15/GeneratedFlight_5.txt
# Smoothing applied and file saved: ./data/smoothed_flights_15/GeneratedFlight_12.txt
# Smoothing applied and file saved: ./data/smoothed_flights_15/GeneratedFlight_10.txt
# Smoothing applied and file saved: ./data/smoothed_flights_15/GeneratedFlight_1.txt
# Smoothing applied and file saved: ./data/smoothed_flights_15/GeneratedFlight_15.txt
# Smoothing applied and file saved: ./data/smoothed_flights_15/GeneratedFlight_13.txt
# Smoothing applied and file saved: ./data/smoothed_flights_15/GeneratedFlight_4.txt
# Smoothing applied and file saved: ./data/smoothed_flights_15/GeneratedFlight_11.txt
# Smoothing applied and file saved: ./data/smoothed_flights_15/GeneratedFlight_9.txt
# Smoothing applied and file saved: ./data/smoothed_flights_15/GeneratedFlight_7.txt
# Smoothing applied and file saved: ./data/smoothed_flights_30/GeneratedFlight_18.txt
# Smoothing applied and file saved: ./data/smoothed_flights_30/GeneratedFlight_14.txt
# Smoothing applied and file saved: ./data/smoothed_flights_30/GeneratedFlight_2.txt
# Smoothing applied and file saved: ./data/smoothed_flights_30/GeneratedFlight_27.txt
# Smoothing applied and file saved: ./data/smoothed_flights_30/GeneratedFlight_8.txt
# Smoothing applied and file saved: ./data/smoothed_flights_30/GeneratedFlight_19.txt
# Smoothing applied and file saved: ./data/smoothed_flights_30/GeneratedFlight_17.txt
# Smoothing applied and file saved: ./data/smoothed_flights_30/GeneratedFlight_28.txt
# Smoothing applied and file saved: ./data/smoothed_flights_30/GeneratedFlight_22.txt
# Smoothing applied and file saved: ./data/smoothed_flights_30/GeneratedFlight_26.txt
# Smoothing applied and file saved: ./data/smoothed_flights_30/GeneratedFlight_16.txt
# Smoothing applied and file saved: ./data/smoothed_flights_30/GeneratedFlight_3.txt
# Smoothing applied and file saved: ./data/smoothed_flights_30/GeneratedFlight_6.txt
# Smoothing applied and file saved: ./data/smoothed_flights_30/GeneratedFlight_5.txt
# Smoothing applied and file saved: ./data/smoothed_flights_30/GeneratedFlight_25.txt
# Smoothing applied and file saved: ./data/smoothed_flights_30/GeneratedFlight_12.txt
# Smoothing applied and file saved: ./data/smoothed_flights_30/GeneratedFlight_10.txt
# Smoothing applied and file saved: ./data/smoothed_flights_30/GeneratedFlight_30.txt
# Smoothing applied and file saved: ./data/smoothed_flights_30/GeneratedFlight_20.txt
# Smoothing applied and file saved: ./data/smoothed_flights_30/GeneratedFlight_1.txt
# Smoothing applied and file saved: ./data/smoothed_flights_30/GeneratedFlight_29.txt
# Smoothing applied and file saved: ./data/smoothed_flights_30/GeneratedFlight_15.txt
# Smoothing applied and file saved: ./data/smoothed_flights_30/GeneratedFlight_13.txt
# Smoothing applied and file saved: ./data/smoothed_flights_30/GeneratedFlight_4.txt
# Smoothing applied and file saved: ./data/smoothed_flights_30/GeneratedFlight_11.txt
# Smoothing applied and file saved: ./data/smoothed_flights_30/GeneratedFlight_23.txt
# Smoothing applied and file saved: ./data/smoothed_flights_30/GeneratedFlight_9.txt
# Smoothing applied and file saved: ./data/smoothed_flights_30/GeneratedFlight_24.txt
# Smoothing applied and file saved: ./data/smoothed_flights_30/GeneratedFlight_7.txt
# Smoothing applied and file saved: ./data/smoothed_flights_30/GeneratedFlight_21.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_32.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_47.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_63.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_51.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_69.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_85.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_18.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_59.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_75.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_34.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_97.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_58.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_37.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_65.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_100.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_43.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_14.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_2.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_76.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_74.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_61.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_89.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_80.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_98.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_27.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_8.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_19.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_17.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_71.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_60.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_64.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_53.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_28.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_22.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_41.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_72.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_26.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_62.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_49.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_94.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_86.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_66.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_44.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_36.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_16.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_90.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_3.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_52.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_38.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_35.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_79.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_91.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_87.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_54.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_6.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_67.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_5.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_40.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_77.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_81.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_70.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_25.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_99.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_56.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_45.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_12.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_83.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_10.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_30.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_39.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_68.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_78.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_48.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_93.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_95.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_20.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_1.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_84.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_29.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_15.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_13.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_50.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_31.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_55.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_4.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_88.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_42.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_73.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_92.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_11.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_82.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_23.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_9.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_24.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_7.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_21.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_46.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_96.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_33.txt
# Smoothing applied and file saved: ./data/smoothed_flights_100/GeneratedFlight_57.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_413.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_204.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_395.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_178.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_32.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_176.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_126.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_47.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_305.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_134.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_172.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_401.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_133.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_185.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_264.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_324.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_403.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_63.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_150.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_420.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_442.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_405.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_474.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_263.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_398.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_251.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_402.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_335.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_143.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_117.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_327.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_51.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_237.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_368.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_351.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_69.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_213.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_495.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_85.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_478.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_255.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_209.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_158.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_500.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_446.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_407.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_18.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_484.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_59.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_107.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_435.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_165.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_287.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_257.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_348.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_397.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_75.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_422.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_240.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_451.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_431.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_34.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_198.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_338.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_97.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_453.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_161.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_462.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_108.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_58.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_37.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_157.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_233.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_211.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_304.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_469.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_219.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_358.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_162.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_228.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_195.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_65.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_118.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_253.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_100.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_339.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_260.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_179.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_282.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_482.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_477.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_362.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_43.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_14.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_468.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_169.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_380.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_140.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_378.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_314.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_488.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_319.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_467.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_428.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_269.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_386.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_334.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_280.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_125.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_2.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_220.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_376.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_289.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_308.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_330.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_196.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_238.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_243.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_347.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_493.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_301.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_285.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_183.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_455.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_357.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_321.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_450.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_337.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_345.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_168.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_76.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_189.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_74.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_147.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight_61.txt
# Smoothing applied and file saved: ./data/smoothed_flights_500/GeneratedFlight
txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1624.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1901.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_729.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_429.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2041.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2646.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_984.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2447.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1797.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1430.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1925.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2278.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2862.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_665.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2627.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1825.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_279.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1706.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_7.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1092.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1034.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1983.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_480.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_343.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1106.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1650.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2779.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1035.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1100.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2750.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1616.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_824.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2045.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1929.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2235.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2563.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_306.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1319.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2286.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2359.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2182.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2965.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2197.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1753.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1022.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2619.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2937.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2002.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_965.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1202.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1051.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2060.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2306.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1472.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_21.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1016.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2843.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1502.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1410.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_46.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2456.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1324.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1534.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_96.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_873.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1284.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2135.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_928.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1498.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2243.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1310.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_156.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2524.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_927.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2345.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_277.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_399.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2156.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_33.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_57.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_123.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1286.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1064.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2205.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2740.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_937.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2969.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2349.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_159.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2612.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1738.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1967.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2291.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1432.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_394.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2759.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2903.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2476.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_1548.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_2249.txt
# Smoothing applied and file saved: ./data/smoothed_flights_3000/GeneratedFlight_702.txt

# %%
# Load adjusted flights
adjusted_flights_dir = './data/adjusted_flights/'
adjusted_flights = load_flight_data(adjusted_flights_dir)

# Load generated flights
generated_flights_dir = './data/generated_flights_30/'
generated_flights = load_flight_data(generated_flights_dir, pattern='GeneratedFlight_*.txt')

# Load generated flights
smoothed_flights_dir = './data/smoothed_flights_30/'
smoothed_flights = load_flight_data(smoothed_flights_dir, pattern='GeneratedFlight_*.txt')

# Create 3D plot
fig = plt.figure(figsize=(20, 20))

# Adjust the view angles: elevation and azimuth
elevation_angle = 30  # Elevation angle in degrees
azimuth_angle = 150   # Azimuth angle in degrees

# Plot adjusted flights
ax1 = fig.add_subplot(131, projection='3d')
plot_flights_3d(adjusted_flights, 'Adjusted Flights', ax1, elevation_angle, azimuth_angle)

# Plot generated flights
ax2 = fig.add_subplot(132, projection='3d')
plot_flights_3d(generated_flights, 'Generated Flights', ax2, elevation_angle, azimuth_angle)

# Plot smoothed flights
ax2 = fig.add_subplot(133, projection='3d')
plot_flights_3d(smoothed_flights, 'Smoothed Flights', ax2, elevation_angle, azimuth_angle)

plt.tight_layout()
plt.show()

# %%
import os
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Function to load and process flight data from a directory
def load_flight_data_from_directory(directory):
    file_pattern = os.path.join(directory, '*.txt')
    files = glob.glob(file_pattern)
    flights = []
    for file_path in files:
        df = pd.read_csv(file_path, delimiter='\t')
        # Drop the 'Time(milli)' column if it exists
        if 'Time(milli)' in df.columns:
            df = df.drop(columns=['Time(milli)'])
        flights.append(df.values)
    return np.array(flights)

# Load adjusted and generated flight data
adjusted_flights = load_flight_data_from_directory('./data/adjusted_flights/')
generated_flights = load_flight_data_from_directory('./data/generated_flights_15/')

# Function to calculate mean and standard deviation across all flight samples
def calculate_mean_and_std(flights):
    mean_flight = np.mean(flights, axis=0)
    std_flight = np.std(flights, axis=0)
    return mean_flight, std_flight

# Calculate mean and std for adjusted and generated flights
mean_adjusted, std_adjusted = calculate_mean_and_std(adjusted_flights)
mean_generated, std_generated = calculate_mean_and_std(generated_flights)

# Plot the comparison between adjusted and generated flight data
def plot_comparison(mean_adjusted, std_adjusted, mean_generated, std_generated):
    columns_to_plot = [
        'LAT(deg)', 'LON(deg)', 'ALT(m)', 'Phi(deg)', 'Theta(deg)', 'Psi(deg)',
        'Vx(m/s)', 'Vy(m/s)', 'Vz(m/s)', 'P(deg/s)', 'Q(deg/s)', 'R(deg/s)',
        'Nx(m/s2)', 'Ny(m/s2)', 'Nz(m/s2)', 'Radial(deg)', 'Distance(m)', 'DeltaAlt:Anv-Tgt(m)',
        'JX', 'JY', 'Throttle'
    ]
    
    fig, axes = plt.subplots(len(columns_to_plot), 1, figsize=(15, 50))
    for i, col in enumerate(columns_to_plot):
        axes[i].plot(mean_adjusted[:, i], label='Adjusted Mean')
        axes[i].fill_between(range(mean_adjusted.shape[0]), 
                             mean_adjusted[:, i] - std_adjusted[:, i], 
                             mean_adjusted[:, i] + std_adjusted[:, i], 
                             color='gray', alpha=0.3, label='Adjusted Std Dev')
        axes[i].plot(mean_generated[:, i], label='Generated Mean', linestyle='--')
        axes[i].fill_between(range(mean_generated.shape[0]), 
                             mean_generated[:, i] - std_generated[:, i], 
                             mean_generated[:, i] + std_generated[:, i], 
                             color='blue', alpha=0.3, label='Generated Std Dev')
        axes[i].set_title(f'{col}')
        axes[i].legend()

    plt.tight_layout()
    plt.show()

# Call the function to plot the comparison
plot_comparison(mean_adjusted, std_adjusted, mean_generated, std_generated)

# %% [raw]
# import numpy as np
# from scipy.linalg import sqrtm
#
# def calculate_frechet_distance_3d(real_data, synthetic_data):
#     """
#     Calculates the Frechet Distance between two 3D datasets by flattening the time dimension.
#
#     Args:
#         real_data (numpy.ndarray): Real data set with shape (n_samples, n_frames, n_features).
#         synthetic_data (numpy.ndarray): Synthetic data set with shape (n_samples, n_frames, n_features).
#
#     Returns:
#         float: Frechet Distance between the distributions of real and synthetic data.
#     """
#     # Reshape to (n_samples * n_frames, n_features) by combining the sample and frame dimensions
#     real_data_flattened = real_data.reshape(-1, real_data.shape[2])
#     synthetic_data_flattened = synthetic_data.reshape(-1, synthetic_data.shape[2])
#
#     # Compute mean and covariance for real and synthetic data
#     mu_real = np.mean(real_data_flattened, axis=0)
#     sigma_real = np.cov(real_data_flattened, rowvar=False)
#
#     mu_synthetic = np.mean(synthetic_data_flattened, axis=0)
#     sigma_synthetic = np.cov(synthetic_data_flattened, rowvar=False)
#
#     # Mean difference squared
#     mean_diff = mu_real - mu_synthetic
#     mean_diff_squared = mean_diff.dot(mean_diff)
#
#     # Covariance mean product and square root
#     cov_mean, _ = sqrtm(sigma_real.dot(sigma_synthetic), disp=False)
#
#     # Handle potential complex values
#     if np.iscomplexobj(cov_mean):
#         cov_mean = cov_mean.real
#
#     # Calculate the Frechet Distance
#     frechet_distance = mean_diff_squared + np.trace(sigma_real + sigma_synthetic - 2 * cov_mean)
#     return frechet_distance
#
# # Example usage
# frechet_distance = calculate_frechet_distance_3d(adjusted_flights, np.array(smoothed_flights))
# print(f"The Frechet Distance is: {frechet_distance}")
